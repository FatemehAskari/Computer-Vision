# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# imshow(improveimg)
img = cv2.imread('images/Q4/2.jpg')

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# gray_img[gray_img>160]=255
gray_img[gray_img<100]=0


plt.imshow(gray_img,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 442.5, 410.5, -0.5)
