# %%
import networkx as nx
import matplotlib.pyplot as plt
import tkinter as tk

# ساخت گراف تصادفی با 10 گره
graph = nx.gnm_random_graph(10, 20)

# رسم گراف
pos = nx.spring_layout(graph, seed=42)
nx.draw(graph, pos, with_labels=True)

plt.show()
